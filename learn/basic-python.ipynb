# %% [markdown]
# Lets do basic python here

# %%
count = 1
count = count + 4
print(count)
count = count - 2
print(count)
count = count * 4
print(count)
count = count / 2
print(count)
# Out:
# 5
# 3
# 12
# 6.0

# %%
from pprint import pprint
data = [1, 2, 3, 4, 5]

pprint(data)
# Out:
# [[1, 2, 3, 4, 5]]
